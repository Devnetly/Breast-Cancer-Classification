# %% [markdown]
# ### Necessary Packages

# %%
import torch
import sys
import dotenv
import os
import torch
import seaborn as sns
import matplotlib.pyplot as plt
sys.path.append('../..')
from src.models import AttentionModel
from torch.utils.data import DataLoader
from torchvision.transforms import Lambda
from src.utils import load_model_from_folder,load_history_from_folder
from src.datasets import TensorDataset
from tqdm.notebook import tqdm
from torchmetrics import F1Score,Accuracy,AUROC,Metric
# Out:
# Key OPENSLIDE_PATH not found in /home/bracs/Breast-Cancer-Detection/.env.
# Key OPENSLIDE_PATH not found in /home/bracs/Breast-Cancer-Detection/.env.

# %% [markdown]
# ### Setup the code to be device agnostic

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device.type)
# Out:
# cuda

# %% [markdown]
# ### Results reproducibility

# %%
torch.manual_seed(0)

# %% [markdown]
# ### Loading envirement variables

# %%
TENSORS_DIR = dotenv.get_key(dotenv.find_dotenv(), "ATT1_RESNET18_TENSORS_DIR")
MODELS_DIR = dotenv.get_key(dotenv.find_dotenv(), "ATT1_RESNET18_MODELS_DIR")
HISTORIES_DIR = dotenv.get_key(dotenv.find_dotenv(), "ATT1_RESNET18_HISTORIES_DIR")

# %%
TRAIN_DIR = os.path.join(TENSORS_DIR, "train")
VAL_DIR = os.path.join(TENSORS_DIR, "val")
TEST_DIR = os.path.join(TENSORS_DIR, "test")

# %%
print(MODELS_DIR)
print(TENSORS_DIR)
print(HISTORIES_DIR)
print(TRAIN_DIR)
print(VAL_DIR)
print(TEST_DIR)
# Out:
# /home/abdelnour/Documents/4eme_anne/S2/projet/models
# /home/abdelnour/Documents/4eme_anne/S2/projet/data/ResNet18_tensors
# /home/abdelnour/Documents/4eme_anne/S2/projet/histories
# /home/abdelnour/Documents/4eme_anne/S2/projet/data/ResNet18_tensors/train
# /home/abdelnour/Documents/4eme_anne/S2/projet/data/ResNet18_tensors/val
# /home/abdelnour/Documents/4eme_anne/S2/projet/data/ResNet18_tensors/test

# %% [markdown]
# ### Global

# %%
BATCH_SIZE = 1
NUM_WORKERS = 0
PREFETCH_FACTOR = None
WEIGHTS_FOLDER  = os.path.join(MODELS_DIR, "attention")
HISTORIES_FOLDER = path = os.path.join(HISTORIES_DIR, "attention")

# %% [markdown]
# ### Load the model

# %%
model = AttentionModel(
    num_classes=3,
    dropout=0.2,
    filters_in=512,
    filters_out=64
).to(device)

# %%
load_model_from_folder(model, WEIGHTS_FOLDER, verbose=True, weights_id=os.path.join('best_weights','1713741442.6637716_epoch=9.pt'))

# %% [markdown]
# ### Learning graph

# %%
history_df = load_history_from_folder(HISTORIES_FOLDER)

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2)

fig.set_size_inches(15, 5)

sns.lineplot(data=history_df, x="epoch", y="loss", hue="split", ax=ax1)
sns.lineplot(data=history_df, x="epoch", y="accuracy", hue="split", ax=ax2)
# Out:
# <Axes: xlabel='epoch', ylabel='accuracy'>

# %% [markdown]
# ### Data Loading

# %%
transfrom = Lambda(lambd=lambda x : torch.unsqueeze(x, dim=0))
datatset = TensorDataset(root=TEST_DIR,transform=transfrom)
loader = DataLoader(dataset=datatset, batch_size=1, shuffle=True)

# %% [markdown]
# ### Inference

# %%
def predict(
    loader : DataLoader,
    model : AttentionModel
) -> tuple[torch.Tensor,torch.Tensor]:
    
    model.eval()

    Y_hat = []
    Y = []

    with torch.inference_mode():

        for x,y in tqdm(loader):

            x,y = x.to(device),y.to(device)

            y_hat = model(x)
            y_hat = torch.squeeze(y_hat)

            y = torch.squeeze(y).item()

            Y.append(y)
            Y_hat.append(y_hat)
    
    Y_hat = torch.vstack(Y_hat)
    Y = torch.tensor(Y)
    Y = Y.squeeze()
    Y = Y.to(device)

    return Y_hat,Y

# %%
Y_hat,Y = predict(loader,model)
# Out:
#   0%|          | 0/87 [00:00<?, ?it/s]

# %%
print(Y_hat.shape,Y.shape)
# Out:
# torch.Size([87, 3]) torch.Size([87])

# %% [markdown]
# ### Computing metrics

# %%
metrics = {
    "accuracy" : Accuracy(task='multiclass',num_classes=3).to(device),
    "f1_score" : F1Score(task='multiclass',num_classes=3,average='macro').to(device),
    "auc" : AUROC(task='multiclass',num_classes=3).to(device)
}

# %%
def compute_metrics(metrics : dict[str,Metric], y : torch.Tensor, y_hat : torch.Tensor) -> dict:

    result = {}

    for name, metric in metrics.items():
        score = metric(y_hat, y)
        result[name] = score.item()

    return  result

# %%
compute_metrics(metrics, Y, Y_hat)
# Out:
# {'accuracy': 0.6206896305084229,
#  'f1_score': 0.5229747295379639,
#  'auc': 0.7883481383323669}
