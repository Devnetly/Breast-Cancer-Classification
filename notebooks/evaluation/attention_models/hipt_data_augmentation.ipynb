# %% [markdown]
# ### Necessary Packages

# %%
import torch
import sys
import dotenv
import os
import torch
import seaborn as sns
import matplotlib.pyplot as plt
sys.path.append('../../..')
from src.models import HIPT_WSI
from torch.utils.data import DataLoader
from torchvision.transforms import Lambda
from src.utils import load_model_from_folder,load_history_from_folder
from src.datasets import TensorDataset
from tqdm.notebook import tqdm
from torchmetrics import F1Score,Accuracy,AUROC,Metric,Precision,Recall

# %% [markdown]
# ### Setup the code to be device agnostic

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device.type)
# Out:
# cuda

# %% [markdown]
# ### Results reproducibility

# %%
torch.manual_seed(0)

# %% [markdown]
# ### Loading envirement variables

# %%
TENSORS_DIR = dotenv.get_key(dotenv.find_dotenv(), "HIPT_TENSORS_DIR")
MODELS_DIR = dotenv.get_key(dotenv.find_dotenv(), "HIPT_MODELS_DIR")
HISTORIES_DIR = dotenv.get_key(dotenv.find_dotenv(), "HIPT_HISTORIES_DIR")

# %%
TRAIN_DIR = os.path.join(TENSORS_DIR, "train")
VAL_DIR = os.path.join(TENSORS_DIR, "val")
TEST_DIR = os.path.join(TENSORS_DIR, "test")

# %%
print(MODELS_DIR)
print(TENSORS_DIR)
print(HISTORIES_DIR)
print(TRAIN_DIR)
print(VAL_DIR)
print(TEST_DIR)
# Out:
# /home/bracs/Desktop/Attention_Models/HIPT/weights
# /media/bracs/08AB3E166632A43D/tensors/hipt_tensors
# /home/bracs/Desktop/Attention_Models/HIPT/histories
# /media/bracs/08AB3E166632A43D/tensors/hipt_tensors/train
# /media/bracs/08AB3E166632A43D/tensors/hipt_tensors/val
# /media/bracs/08AB3E166632A43D/tensors/hipt_tensors/test

# %% [markdown]
# ### Global

# %%
BATCH_SIZE = 1
NUM_WORKERS = 0
PREFETCH_FACTOR = None
WEIGHTS_FOLDER  = os.path.join(MODELS_DIR)
HISTORIES_FOLDER = path = os.path.join(HISTORIES_DIR)

# %% [markdown]
# ### Load the model

# %%
model = HIPT_WSI(
    dropout=0.2
).to(device)
# Out:
# /home/bracs/.local/lib/python3.10/site-packages/torch/nn/modules/transformer.py:286: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")

# %%
load_model_from_folder(model, WEIGHTS_FOLDER, verbose=True)
# Out:
# loading weights with name : 1716450175.7177708.pt

# %% [markdown]
# ### Learning graph

# %%
history_df = load_history_from_folder(HISTORIES_FOLDER)

# %%
train_his = history_df[history_df["split"] == "train"]
val_his = history_df[history_df["split"] == "val"]

# %%
def plot_loss_accuracy(train_history, val_history, title):
    fig, ax = plt.subplots(ncols=2)
    fig.suptitle(title, fontsize=18)
    fig.set_size_inches(20,6)

    ax[0].plot(train_history['epoch'], train_history['loss'], label='Training Loss', color='green')
    ax[0].plot(val_history['epoch'], val_his['loss'], label='Validation Loss', color='midnightblue')
    ax[0].set_title('Classifier Loss History')
    ax[0].set_xlabel('Epochs')
    ax[0].set_ylabel('Loss')
    ax[0].legend()
    ax[0].grid(linestyle='dashed', dash_joinstyle='miter', alpha=0.75, zorder=1, color='gray')

    ax[1].plot(train_history['epoch'], train_history['accuracy'], label='Training Accuracy', color='green')
    ax[1].plot(val_history['epoch'], val_his['accuracy'], label='Validation Accuracy', color='midnightblue')
    ax[1].set_title('Classifier Accuracy History')
    ax[1].set_xlabel('Epochs')
    ax[1].set_ylabel('Accuracy')
    ax[1].legend()
    ax[1].grid(linestyle='dashed', dash_joinstyle='miter', alpha=0.75, zorder=1, color='gray')

# %%
plot_loss_accuracy(train_history=train_his, val_history=val_his, title="Classifier: HIPT")

# %% [markdown]
# ### Data Loading

# %%
transfrom = Lambda(lambd=lambda x : torch.permute(x, dims=(1,2,0)).reshape(-1, x.shape[0]))
datatset = TensorDataset(root=TEST_DIR,transform=transfrom)
loader = DataLoader(dataset=datatset, batch_size=1, shuffle=True)

# %% [markdown]
# ### Inference

# %%
def predict(
    loader : DataLoader,
    model : HIPT_WSI
) -> tuple[torch.Tensor,torch.Tensor]:
    
    model.eval()

    Y_hat = []
    Y = []

    with torch.inference_mode():

        for x,y in tqdm(loader):

            x,y = x.to(device),y.to(device)

            y_hat = model(x)
            y_hat = torch.squeeze(y_hat)

            y = torch.squeeze(y).item()

            Y.append(y)
            Y_hat.append(y_hat)
    
    Y_hat = torch.vstack(Y_hat)
    Y = torch.tensor(Y)
    Y = Y.squeeze()
    Y = Y.to(device)

    return Y_hat,Y

# %%
Y_hat,Y = predict(loader,model)
# Out:
#   0%|          | 0/87 [00:00<?, ?it/s]

# %%
print(Y_hat.shape,Y.shape)
# Out:
# torch.Size([87, 3]) torch.Size([87])

# %% [markdown]
# ### Computing metrics

# %%
metrics = {
    "accuracy" : Accuracy(task='multiclass',num_classes=3).to(device),
    "f1_score" : F1Score(task='multiclass',num_classes=3,average='macro').to(device),
    "auc" : AUROC(task='multiclass',num_classes=3).to(device),
    "recall" : Recall(task='multiclass',num_classes=3,average='macro').to(device),
    "precision" : Precision(task='multiclass',num_classes=3,average='macro').to(device),
}

# %%
def compute_metrics(metrics : dict[str,Metric], y : torch.Tensor, y_hat : torch.Tensor) -> dict:

    result = {}

    for name, metric in metrics.items():
        score = metric(y_hat, y)
        result[name] = score.item()

    return  result

# %%
compute_metrics(metrics, Y, Y_hat)
# Out:
# {'accuracy': 0.7241379022598267,
#  'f1_score': 0.6813071966171265,
#  'auc': 0.8124876022338867,
#  'recall': 0.6888587474822998,
#  'precision': 0.7298567295074463}
